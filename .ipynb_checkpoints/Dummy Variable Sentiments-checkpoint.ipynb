# %%
import pandas as pd
import numpy as np

# %%
texas = pd.read_csv('finaldb.csv')

# %%
texas.head()
# Out:
#    num  execution   lastname firstname  tdcjnumber  age dateofexecution  \
# 0  NaN         12     Barney   Jeffery         714   34      1986-04-16
# 1  0.0         13  Pinkerton       Jay         686   25      1986-05-15
# 2  1.0         14   Esquivel      Rudy         606   50      1986-06-09
# 3  2.0         15      Brock   Kenneth         522   37      1986-06-19
# 4  3.0         16     Woolls     Randy         646   36      1986-08-20
#
#        race     county   finalstatement    ...     prioroccupation  \
# 0     white     Harris  statement given    ...                 NaN
# 1     white     Nueces  statement given    ...                 NaN
# 2  hispanic     Harris  statement given    ...                 NaN
# 3     white     Harris  statement given    ...                 NaN
# 4     white  Tom Green  statement given    ...                 NaN
#
#    priorrecord                  crime        victim numofvictims remorse  \
# ...
